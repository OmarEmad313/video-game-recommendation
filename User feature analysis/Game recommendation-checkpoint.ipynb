# %%
import pandas as pd
import numpy as np

# %%
# data viz
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
# apply some cool styling
plt.style.use("ggplot")
rcParams['figure.figsize'] = (12,  6)

# %%
userDataset = pd.read_csv('user_dataset.csv')

# %%
dfUsers = pd.DataFrame(userDataset)
#renaming features

dfUsers.rename(columns={'Games you love (at least 5 games)': 'game'},
          inplace=True, errors='raise')

# %%
#droping unuseful columns
dfUsers.drop(['Timestamp', 'Username'], axis = 1, inplace = True)

# %%
list(dfUsers.columns)
# Out:
# ["  Hello, what's your Age?  ",
#  'Gender',
#  'Education',
#  'Where would you place yourself on the scale below in hours per day of gaming? (كم ساعه تلعب في اليوم)',
#  '  Platform you play on  ',
#  'Type of games you like to play (genres) ',
#  'game',
#  'Other games (please add as many as you desire)']

# %%
display(dfUsers)
# Out:
#        Hello, what's your Age?    Gender  \
# 0                             20    Male
# 1                             20    Male
# 2                             20    Male
# 3                             20    Male
# 4                             34  Female
# ...                          ...     ...
# 1909                          17    Male
# 1910                          17    Male
# 1911                          17    Male
# 1912                          17    Male
# 1913                          18    Male
#
#                                   Education  \
# 0     Private universities(الجامعات الخاصة)
# 1     Private universities(الجامعات الخاصة)
# 2     Private universities(الجامعات الخاصة)
# 3     Private universities(الجامعات الخاصة)
# 4     Private universities(الجامعات الخاصة)
# ...                                     ...
# 1909  Private universities(الجامعات الخاصة)
# 1910  Private universities(الجامعات الخاصة)
# 1911  Private universities(الجامعات الخاصة)
# ...

# %%
#creating the user id column
dfUsers["id"]=dfUsers.index+1
dfUsers = dfUsers[['id'] + [x for x in dfUsers.columns if x != 'id']]

# %%
dfUsers["game"].unique
# Out:
# <bound method Series.unique of 0                       Path of Exile
# 1                      Stardew Valley
# 2       DARK SOULS III Deluxe Edition
# 3                         Final Match
# 4                    FINAL FANTASY IX
#                     ...
# 1909                      Final Match
# 1910                         NBA 2K17
# 1911         Abrix 2 - Silver version
# 1912     Call of Duty®: Black Ops III
# 1913                         NBA 2K17
# Name: game, Length: 1914, dtype: object>

# %% [markdown]
# Games Dataset

# %%
gamesDataset = pd.read_csv('games_dataset.csv')

# %%
dfGames = pd.DataFrame(gamesDataset)

# %%
dfGames.rename(columns={'name': 'game'},
          inplace=True, errors='raise')
display(dfGames)
# Out:
#                                                      url types  \
# 0        https://store.steampowered.com/app/379720/DOOM/   app
# 1      https://store.steampowered.com/app/578080/PLAY...   app
# 2      https://store.steampowered.com/app/637090/BATT...   app
# 3        https://store.steampowered.com/app/221100/DayZ/   app
# 4      https://store.steampowered.com/app/8500/EVE_On...   app
# ...                                                  ...   ...
# 40828  https://store.steampowered.com/app/899836/Rock...   app
# 40829  https://store.steampowered.com/app/899832/Rock...   app
# 40830  https://store.steampowered.com/app/906840/Fant...   app
# 40831  https://store.steampowered.com/app/906635/Mega...   app
# 40832  https://store.steampowered.com/app/908000/Stor...   app
#
#                                                     game  \
# 0                                                   DOOM
# 1                          PLAYERUNKNOWN'S BATTLEGROUNDS
# ...

# %%
df=pd.merge(dfUsers,dfGames)
df["game"].unique
# Out:
# <bound method Series.unique of 0                 Path of Exile
# 1                 Path of Exile
# 2                 Path of Exile
# 3                 Path of Exile
# 4                 Path of Exile
#                  ...
# 1866    Counter-Strike Complete
# 1867    Counter-Strike Complete
# 1868    Counter-Strike Complete
# 1869    Counter-Strike Complete
# 1870    Counter-Strike Complete
# Name: game, Length: 1871, dtype: object>

# %%
display(df)
# Out:
#         id   Hello, what's your Age?    Gender  \
# 0        1                          20    Male
# 1      237                          25  Female
# 2      270                          32    Male
# 3      979                          19  Female
# 4     1088                          26    Male
# ...    ...                         ...     ...
# 1866  1775                          17    Male
# 1867  1802                          21    Male
# 1868  1841                          19    Male
# 1869  1865                          19    Male
# 1870  1877                          22    Male
#
#                                         Education  \
# 0           Private universities(الجامعات الخاصة)
# 1           governments schools(المدارس الحكومية)
# 2           Private universities(الجامعات الخاصة)
# 3           governments schools(المدارس الحكومية)
# 4           Private universities(الجامعات الخاصة)
# ...                                           ...
# ...

# %% [markdown]
# # The merged dataset

# %%
dataset = pd.read_csv('dataset.csv')

# %%
df= pd.DataFrame(dataset)

# %%
df.rename(columns={'Where would you place yourself on the scale below in hours per day of gaming? (كم ساعه تلعب في اليوم)': 'daily hours'},
          inplace=True, errors='raise')
df.rename(columns={'favorite genres': 'favorite_genres'},
          inplace=True, errors='raise')
df.rename(columns={'  Platforms': 'platforms'},
          inplace=True, errors='raise')

# %%
df.describe()
# Out:
#         Unnamed: 0           id  daily hours  achievements
# count  1871.000000  1871.000000  1871.000000   1360.000000
# mean    935.000000   944.083378     3.694281     58.454412
# std     540.255495   551.017993     2.400215     31.652375
# min       0.000000     1.000000     0.000000      1.000000
# 25%     467.500000   468.500000     2.000000     49.000000
# 50%     935.000000   936.000000     3.000000     55.000000
# 75%    1402.500000  1418.500000     5.000000     77.000000
# max    1870.000000  1914.000000    10.000000    120.000000

# %%
df['age'] = df['age'].astype(int)
df['daily hours'] = df['daily hours'].astype(int)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, age, Gender, Education, daily hours, platforms, favorite_genres, game, Other games , url, types, desc_snippet, recent_reviews, all_reviews, release_date, developer, publisher, popular_tags, game_details, languages, achievements, genre, game_description, mature_content, minimum_requirements, recommended_requirements, original_price, discount_price]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_melt = df.assign(favorite_genres=df.favorite_genres.str.split(";"))

# %%
df_melt.drop(['Unnamed: 0', 'id'], axis = 1, inplace = True)

# %%
df_melt=df_melt.explode("favorite_genres")

# %%
df_melt["id"]=df_melt.index+1
df_melt = df_melt[['id'] + [x for x in df_melt.columns if x != 'id']]

# %%
df_melt = df_melt.assign(platforms=df_melt.platforms.str.split(";"))

# %%
df_melt=df_melt.explode("platforms")

# %%
display(df_melt)
# Out:
#         id  age  Gender                              Education  daily hours  \
# 0        1   20    Male  Private universities(الجامعات الخاصة)            3
# 1        2   25  Female  governments schools(المدارس الحكومية)            2
# 2        3   32    Male  Private universities(الجامعات الخاصة)            7
# 2        3   32    Male  Private universities(الجامعات الخاصة)            7
# 2        3   32    Male  Private universities(الجامعات الخاصة)            7
# ...    ...  ...     ...                                    ...          ...
# 1869  1870   19    Male            Private schools(مدارس خاصة)            4
# 1870  1871   22    Male  Private universities(الجامعات الخاصة)            4
# 1870  1871   22    Male  Private universities(الجامعات الخاصة)            4
# 1870  1871   22    Male  Private universities(الجامعات الخاصة)            4
# 1870  1871   22    Male  Private universities(الجامعات الخاصة)            4
#
# ...

# %%
df=df_melt

# %%
first_column = df.iloc[:, 0]

# %%
df=df.reset_index(drop=True)

# %%
display(df)
# Out:
#          id  age  Gender                              Education  daily hours  \
# 0         1   20    Male  Private universities(الجامعات الخاصة)            3
# 1         2   25  Female  governments schools(المدارس الحكومية)            2
# 2         3   32    Male  Private universities(الجامعات الخاصة)            7
# 3         3   32    Male  Private universities(الجامعات الخاصة)            7
# 4         3   32    Male  Private universities(الجامعات الخاصة)            7
# ...     ...  ...     ...                                    ...          ...
# 13104  1870   19    Male            Private schools(مدارس خاصة)            4
# 13105  1871   22    Male  Private universities(الجامعات الخاصة)            4
# 13106  1871   22    Male  Private universities(الجامعات الخاصة)            4
# 13107  1871   22    Male  Private universities(الجامعات الخاصة)            4
# 13108  1871   22    Male  Private universities(الجامعات الخاصة)            4
#
# ...

# %%
#df.to_csv('databeta.csv')

# %%
corrmat = df.corr()
hm = sns.heatmap(corrmat, 
                 cbar=True, 
                 annot=True, 
                 square=True, 
                 fmt='.2f', 
                 annot_kws={'size': 10}, 
                 yticklabels=df.columns, 
                 xticklabels=df.columns, 
                 cmap="Spectral_r")
plt.show()
# Out:
# C:\Users\USCS\AppData\Local\Temp\ipykernel_16124\4106598189.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
sns.scatterplot(x="age",y="game", data=df, palette="Dark2", s=80)
# Out:
# C:\Users\USCS\AppData\Local\Temp\ipykernel_16124\133912169.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="age",y="game", data=df, palette="Dark2", s=80)
# <AxesSubplot: xlabel='age', ylabel='game'>

# %%
sns.scatterplot(x="daily hours",y="game", data=df, palette="Dark2", s=80)
# Out:
# C:\Users\USCS\AppData\Local\Temp\ipykernel_16124\3358638947.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="daily hours",y="game", data=df, palette="Dark2", s=80)
# <AxesSubplot: xlabel='daily hours', ylabel='game'>

# %%
sns.scatterplot(x="Gender",y="favorite_genres", hue="favorite_genres", data=df, palette="Dark2", s=80)
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='favorite_genres'>

# %%
sns.scatterplot(x="Education",y="favorite_genres", hue="favorite_genres", data=df, palette="Dark2", s=200)
# Out:
# <AxesSubplot: xlabel='Education', ylabel='favorite_genres'>

# %%
sns.scatterplot(x="age",y="favorite_genres", data=df, palette="Dark2", s=200)

# %%
sns.scatterplot(x="Gender",y="platforms", hue="platforms", data=df, palette="Dark2", s=80)

# %%
df["Gender"].value_counts(normalize=True).plot(kind="bar")

# %%
df["platforms"].value_counts(normalize=True).plot(kind="bar")

# %%
df["favorite_genres"].value_counts(normalize=True).plot(kind="bar")

# %%
df["game"].value_counts(normalize=True).plot(kind="bar")

# %%
df["daily hours"].value_counts(normalize=True).plot(kind="bar")

# %%
df["Education"].value_counts(normalize=True).plot(kind="bar")

# %%
sns.catplot(x="Gender", y="age", data=df, kind="box", aspect=1.5)

# %%
sns.catplot(x="age", y="daily hours", data=df, kind="box", aspect=3)

# %%
sns.pairplot(df)

# %%
df.info()

# %%
df["daily hours"].value_counts()
